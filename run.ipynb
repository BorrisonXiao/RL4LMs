# %%
# %cd drive/MyDrive/RL/project/RL4LMs/
# Out:
# /content/drive/MyDrive/RL/project/RL4LMs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install -e .

# %%
# # For using Colab Premium GPU (A100)
# !pip3 install torch==1.9.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# # Restart the runtime for installation
# import os
# os.kill(os.getpid(), 9)

# %%
# import wandb
# wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python ./scripts/training/train_text_generation.py --config_path scripts/training/task_configs/iwslt2017/en_zh_supervised.yml
# Out:
# 2022-11-28 15:50:14.744843: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Downloading: 100% 275/275 [00:00<00:00, 297kB/s]
# Downloading: 100% 1.44M/1.44M [00:00<00:00, 16.8MB/s]
# Downloading: 100% 65.0/65.0 [00:00<00:00, 69.7kB/s]
# Downloading builder script: 100% 8.17k/8.17k [00:00<00:00, 7.23MB/s]
# Downloading and preparing dataset iwslt2017/iwslt2017-de-en to /root/.cache/huggingface/datasets/iwslt2017/iwslt2017-de-en/1.0.0/03ce9110373117c6f6687719f49f269486a8cd49dcad2527993a316cd4b6ad49...
# Downloading data: 100% 16.8M/16.8M [00:00<00:00, 53.9MB/s]
# Dataset iwslt2017 downloaded and prepared to /root/.cache/huggingface/datasets/iwslt2017/iwslt2017-de-en/1.0.0/03ce9110373117c6f6687719f49f269486a8cd49dcad2527993a316cd4b6ad49. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 484.55it/s]
# Preparing dataset: 100% 206112/206112 [00:12<00:00, 16335.39it/s]
# WARNING:datasets.builder:Found cached dataset iwslt2017 (/root/.cache/huggingface/datasets/iwslt2017/iwslt2017-de-en/1.0.0/03ce9110373117c6f6687719f49f269486a8cd49dcad2527993a316cd4b6ad49)
# 100% 3/3 [00:00<00:00, 955.20it/s]
# Preparing dataset: 100% 888/888 [00:00<00:00, 17684.71it/s]
# WARNING:datasets.builder:Found cached dataset iwslt2017 (/root/.cache/huggingface/datasets/iwslt2017/iwslt2017-de-en/1.0.0/03ce9110373117c6f6687719f49f269486a8cd49dcad2527993a316cd4b6ad49)
# 100% 3/3 [00:00<00:00, 943.25it/s]
# Preparing dataset: 100% 8079/8079 [00:00<00:00, 17690.22it/s]
# 100% 207/207 [00:11<00:00, 17.48ba/s]
# Downloading: 100% 711/711 [00:00<00:00, 576kB/s]
# Downloading: 100% 1.23G/1.23G [00:19<00:00, 68.3MB/s]
# Predicting: 100% 18/18 [01:26<00:00,  4.80s/it]
# Computing metrics:   0% 0/6 [00:00<?, ?it/s]/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/metric.py:133: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   self._metric = load_metric("rouge")
#
# Downloading builder script: 5.60kB [00:00, 4.36MB/s]
# Computing metrics:  17% 1/6 [00:01<00:07,  1.49s/it]
# Downloading builder script: 6.06kB [00:00, 5.23MB/s]
#
# Downloading extra modules: 4.07kB [00:00, 3.59MB/s]
# Computing metrics:  33% 2/6 [00:02<00:05,  1.48s/it]
# Downloading builder script: 8.10kB [00:00, 6.73MB/s]
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# https://huggingface.co/roberta-large/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp9ho4106i
#
# Downloading: 100% 482/482 [00:00<00:00, 376kB/s]
# storing https://huggingface.co/roberta-large/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# creating metadata file for /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# https://huggingface.co/roberta-large/resolve/main/vocab.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp295b4mnw
#
# Downloading:   0% 0.00/878k [00:00<?, ?B/s]
# Downloading: 100% 878k/878k [00:00<00:00, 5.35MB/s]
# storing https://huggingface.co/roberta-large/resolve/main/vocab.json in cache at /root/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab
# creating metadata file for /root/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab
# https://huggingface.co/roberta-large/resolve/main/merges.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpoz8td_f_
#
# Downloading:   0% 0.00/446k [00:00<?, ?B/s]
# Downloading: 100% 446k/446k [00:00<00:00, 3.13MB/s]
# storing https://huggingface.co/roberta-large/resolve/main/merges.txt in cache at /root/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# creating metadata file for /root/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/roberta-large/resolve/main/vocab.json from cache at /root/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab
# loading file https://huggingface.co/roberta-large/resolve/main/merges.txt from cache at /root/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/roberta-large/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/roberta-large/resolve/main/tokenizer_config.json from cache at None
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/roberta-large/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373
# Model config RobertaConfig {
#   "_name_or_path": "roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# https://huggingface.co/roberta-large/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpf4wuf026
#
# Downloading:   0% 0.00/1.33G [00:00<?, ?B/s]
# Downloading:   0% 4.01M/1.33G [00:00<00:33, 42.0MB/s]
# Downloading:   1% 8.17M/1.33G [00:00<00:32, 43.0MB/s]
# Downloading:   1% 12.5M/1.33G [00:00<00:32, 44.0MB/s]
# Downloading:   1% 18.2M/1.33G [00:00<00:27, 50.5MB/s]
# Downloading:   2% 24.1M/1.33G [00:00<00:25, 54.4MB/s]
# Downloading:   2% 29.4M/1.33G [00:00<00:25, 54.7MB/s]
# Downloading:   3% 34.6M/1.33G [00:00<00:26, 53.3MB/s]
# Downloading:   3% 39.7M/1.33G [00:00<00:26, 52.3MB/s]
# Downloading:   3% 44.7M/1.33G [00:00<00:26, 51.6MB/s]
# Downloading:   4% 49.6M/1.33G [00:01<00:27, 49.8MB/s]
# Downloading:   4% 54.3M/1.33G [00:01<00:29, 46.9MB/s]
# Downloading:   4% 60.0M/1.33G [00:01<00:27, 50.3MB/s]
# Downloading:   5% 65.6M/1.33G [00:01<00:25, 52.7MB/s]
# Downloading:   5% 70.7M/1.33G [00:01<00:27, 48.4MB/s]
# Downloading:   6% 75.4M/1.33G [00:01<00:28, 46.9MB/s]
# Downloading:   6% 79.9M/1.33G [00:01<00:28, 46.4MB/s]
# Downloading:   6% 85.2M/1.33G [00:01<00:27, 49.0MB/s]
# Downloading:   7% 91.5M/1.33G [00:01<00:24, 53.8MB/s]
# Downloading:   7% 96.7M/1.33G [00:02<00:25, 52.2MB/s]
# Downloading:   7% 102M/1.33G [00:02<00:26, 49.2MB/s]
# Downloading:   8% 108M/1.33G [00:02<00:24, 53.2MB/s]
# Downloading:   8% 113M/1.33G [00:02<00:25, 50.9MB/s]
# Downloading:   9% 118M/1.33G [00:02<00:30, 42.2MB/s]
# Downloading:   9% 122M/1.33G [00:02<00:33, 38.8MB/s]
# Downloading:   9% 126M/1.33G [00:02<00:33, 38.3MB/s]
# Downloading:  10% 130M/1.33G [00:02<00:32, 39.4MB/s]
# Downloading:  10% 135M/1.33G [00:02<00:31, 41.3MB/s]
# Downloading:  10% 139M/1.33G [00:03<00:31, 41.0MB/s]
# Downloading:  10% 143M/1.33G [00:03<00:31, 40.8MB/s]
# Downloading:  11% 149M/1.33G [00:03<00:26, 47.2MB/s]
# Downloading:  11% 154M/1.33G [00:03<00:25, 49.9MB/s]
# Downloading:  12% 159M/1.33G [00:03<00:24, 50.8MB/s]
# Downloading:  12% 164M/1.33G [00:03<00:24, 51.7MB/s]
# Downloading:  12% 169M/1.33G [00:03<00:27, 46.2MB/s]
# Downloading:  13% 174M/1.33G [00:03<00:27, 45.6MB/s]
# Downloading:  13% 178M/1.33G [00:03<00:29, 42.0MB/s]
# Downloading:  14% 184M/1.33G [00:04<00:27, 45.4MB/s]
# Downloading:  14% 189M/1.33G [00:04<00:26, 45.9MB/s]
# Downloading:  14% 194M/1.33G [00:04<00:24, 50.0MB/s]
# Downloading:  15% 201M/1.33G [00:04<00:22, 54.4MB/s]
# Downloading:  15% 206M/1.33G [00:04<00:23, 51.9MB/s]
# Downloading:  16% 212M/1.33G [00:04<00:21, 55.4MB/s]
# Downloading:  16% 217M/1.33G [00:04<00:22, 53.2MB/s]
# Downloading:  16% 223M/1.33G [00:04<00:22, 53.9MB/s]
# Downloading:  17% 229M/1.33G [00:04<00:20, 57.2MB/s]
# Downloading:  17% 234M/1.33G [00:05<00:22, 52.1MB/s]
# Downloading:  18% 240M/1.33G [00:05<00:21, 54.0MB/s]
# Downloading:  18% 246M/1.33G [00:05<00:21, 55.6MB/s]
# Downloading:  18% 251M/1.33G [00:05<00:21, 54.2MB/s]
# Downloading:  19% 256M/1.33G [00:05<00:21, 53.1MB/s]
# Downloading:  19% 263M/1.33G [00:05<00:20, 56.8MB/s]
# Downloading:  20% 268M/1.33G [00:05<00:20, 55.1MB/s]
# Downloading:  20% 274M/1.33G [00:05<00:19, 57.8MB/s]
# Downloading:  21% 280M/1.33G [00:05<00:19, 57.8MB/s]
# Downloading:  21% 285M/1.33G [00:06<00:21, 53.5MB/s]
# Downloading:  21% 291M/1.33G [00:06<00:20, 55.6MB/s]
# Downloading:  22% 297M/1.33G [00:06<00:20, 54.7MB/s]
# Downloading:  22% 302M/1.33G [00:06<00:19, 55.8MB/s]
# Downloading:  23% 308M/1.33G [00:06<00:19, 56.0MB/s]
# Downloading:  23% 313M/1.33G [00:06<00:19, 57.2MB/s]
# Downloading:  24% 320M/1.33G [00:06<00:18, 59.9MB/s]
# Downloading:  24% 325M/1.33G [00:06<00:23, 46.1MB/s]
# Downloading:  24% 330M/1.33G [00:06<00:22, 47.1MB/s]
# Downloading:  25% 336M/1.33G [00:07<00:21, 51.0MB/s]
# Downloading:  25% 341M/1.33G [00:07<00:22, 47.3MB/s]
# Downloading:  25% 346M/1.33G [00:07<00:21, 48.8MB/s]
# Downloading:  26% 351M/1.33G [00:07<00:21, 48.7MB/s]
# Downloading:  26% 357M/1.33G [00:07<00:20, 51.9MB/s]
# Downloading:  27% 363M/1.33G [00:07<00:19, 54.8MB/s]
# Downloading:  27% 368M/1.33G [00:07<00:19, 52.9MB/s]
# Downloading:  27% 373M/1.33G [00:07<00:20, 51.1MB/s]
# Downloading:  28% 378M/1.33G [00:07<00:20, 50.8MB/s]
# Downloading:  28% 385M/1.33G [00:08<00:18, 54.7MB/s]
# Downloading:  29% 390M/1.33G [00:08<00:17, 56.9MB/s]
# Downloading:  29% 397M/1.33G [00:08<00:17, 58.9MB/s]
# Downloading:  30% 403M/1.33G [00:08<00:16, 62.3MB/s]
# Downloading:  30% 409M/1.33G [00:08<00:16, 60.1MB/s]
# Downloading:  31% 415M/1.33G [00:08<00:18, 54.4MB/s]
# Downloading:  31% 421M/1.33G [00:08<00:17, 56.7MB/s]
# Downloading:  31% 427M/1.33G [00:08<00:19, 50.4MB/s]
# Downloading:  32% 432M/1.33G [00:08<00:19, 50.3MB/s]
# Downloading:  32% 437M/1.33G [00:09<00:18, 52.0MB/s]
# Downloading:  33% 442M/1.33G [00:09<00:18, 51.3MB/s]
# Downloading:  33% 448M/1.33G [00:09<00:17, 53.5MB/s]
# Downloading:  33% 453M/1.33G [00:09<00:17, 54.4MB/s]
# Downloading:  34% 458M/1.33G [00:09<00:17, 54.9MB/s]
# Downloading:  34% 464M/1.33G [00:09<00:17, 54.4MB/s]
# Downloading:  35% 470M/1.33G [00:09<00:16, 57.1MB/s]
# Downloading:  35% 476M/1.33G [00:09<00:15, 59.7MB/s]
# Downloading:  35% 482M/1.33G [00:09<00:16, 56.1MB/s]
# Downloading:  36% 487M/1.33G [00:09<00:16, 55.8MB/s]
# Downloading:  36% 494M/1.33G [00:10<00:15, 59.5MB/s]
# Downloading:  37% 499M/1.33G [00:10<00:15, 59.5MB/s]
# Downloading:  37% 505M/1.33G [00:10<00:24, 36.1MB/s]
# Downloading:  38% 512M/1.33G [00:10<00:20, 43.4MB/s]
# Downloading:  38% 518M/1.33G [00:10<00:18, 47.5MB/s]
# Downloading:  87% 1.16G/1.33G [00:24<00:03, 47.8MB/s]
# Downloading:  87% 1.16G/1.33G [00:25<00:06, 29.5MB/s]
# Downloading:  88% 1.17G/1.33G [00:25<00:04, 38.4MB/s]
# Downloading:  88% 1.17G/1.33G [00:25<00:03, 46.0MB/s]
# Downloading:  89% 1.18G/1.33G [00:25<00:03, 51.5MB/s]
# Downloading:  89% 1.19G/1.33G [00:25<00:02, 52.8MB/s]
# Downloading:  90% 1.19G/1.33G [00:25<00:02, 50.5MB/s]
# Downloading:  90% 1.20G/1.33G [00:25<00:03, 44.2MB/s]
# Downloading:  90% 1.20G/1.33G [00:26<00:02, 46.0MB/s]
# Downloading:  91% 1.21G/1.33G [00:26<00:02, 47.8MB/s]
# Downloading:  91% 1.21G/1.33G [00:26<00:02, 46.5MB/s]
# Downloading:  91% 1.22G/1.33G [00:26<00:02, 47.7MB/s]
# Downloading:  92% 1.22G/1.33G [00:26<00:02, 49.2MB/s]
# Downloading:  92% 1.22G/1.33G [00:26<00:02, 49.2MB/s]
# Downloading:  93% 1.23G/1.33G [00:26<00:02, 50.1MB/s]
# Downloading:  93% 1.23G/1.33G [00:26<00:01, 51.6MB/s]
# Downloading:  93% 1.24G/1.33G [00:26<00:01, 52.7MB/s]
# Downloading:  94% 1.25G/1.33G [00:26<00:01, 53.9MB/s]
# Downloading:  94% 1.25G/1.33G [00:27<00:01, 52.0MB/s]
# Downloading:  95% 1.26G/1.33G [00:27<00:01, 55.5MB/s]
# Downloading:  95% 1.26G/1.33G [00:27<00:01, 56.0MB/s]
# Downloading:  95% 1.27G/1.33G [00:27<00:01, 51.3MB/s]
# Downloading:  96% 1.27G/1.33G [00:27<00:01, 49.9MB/s]
# Downloading:  96% 1.28G/1.33G [00:27<00:01, 51.3MB/s]
# Downloading:  97% 1.28G/1.33G [00:27<00:01, 49.0MB/s]
# Downloading:  97% 1.29G/1.33G [00:27<00:00, 49.5MB/s]
# Downloading:  97% 1.29G/1.33G [00:27<00:00, 50.9MB/s]
# Downloading:  98% 1.30G/1.33G [00:28<00:00, 54.1MB/s]
# Downloading:  98% 1.30G/1.33G [00:28<00:00, 52.6MB/s]
# Downloading:  98% 1.31G/1.33G [00:28<00:00, 53.2MB/s]
# Downloading:  99% 1.31G/1.33G [00:28<00:00, 57.4MB/s]
# Downloading:  99% 1.32G/1.33G [00:28<00:00, 57.1MB/s]
# Downloading: 100% 1.33G/1.33G [00:28<00:00, 49.8MB/s]
# storing https://huggingface.co/roberta-large/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352
# creating metadata file for /root/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352
# loading weights file https://huggingface.co/roberta-large/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352
# All the weights of RobertaModel were initialized from the model checkpoint at roberta-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaModel for predictions without further training.
# Computing metrics:  50% 3/6 [00:42<00:56, 18.92s/it]
# Downloading builder script: 7.65kB [00:00, 5.34MB/s]
# Computing metrics:  67% 4/6 [00:43<00:23, 11.67s/it]
# Downloading builder script: 9.52kB [00:00, 7.90MB/s]
# Computing metrics:  83% 5/6 [00:43<00:07,  7.65s/it][I 221128 15:53:46 texts:33] Loading predictions for
# [nltk_data] Downloading package punkt to
# [nltk_data]     /usr/local/lib/python3.7/dist-
# [nltk_data]     packages/data/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Computing metrics: 100% 6/6 [00:44<00:00,  7.40s/it]
# Predicting:  16% 26/162 [01:45<09:12,  4.06s/it]
# Traceback (most recent call last):
#   File "./scripts/training/train_text_generation.py", line 90, in <module>
#     args.log_to_wandb,
#   File "./scripts/training/train_text_generation.py", line 55, in main
#     trainer.train_and_eval()
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/training_utils.py", line 314, in train_and_eval
#     self._evaluate_on_datapools(epoch=0)
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/training_utils.py", line 259, in _evaluate_on_datapools
#     generation_kwargs=self._gen_kwargs
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/utils_supervised.py", line 34, in evaluate_on_samples
#     model, tokenizer, samples, batch_size, max_prompt_length, generation_kwargs)
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/utils_supervised.py", line 277, in generate_on_samples
#     model, tokenizer, batch, max_prompt_length, generation_kwargs)
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/utils_supervised.py", line 59, in generate_text
#     generation_kwargs)
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/utils_supervised.py", line 104, in generate
#     **generation_kwargs_)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py", line 1325, in generate
#     **model_kwargs,
#   File "/usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py", line 2232, in beam_search
#     beam_indices = tuple((beam_indices[beam_idx[i]] + (beam_idx[i],) for i in range(len(beam_indices))))
#   File "/usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py", line 2232, in <genexpr>
#     beam_indices = tuple((beam_indices[beam_idx[i]] + (beam_idx[i],) for i in range(len(beam_indices))))
# KeyboardInterrupt

# %%
# !nvidia-smi

# %%
# from transformers import (
#   T5Tokenizer,
#   MT5ForConditionalGeneration,
#   Text2TextGenerationPipeline,
# )

# path = "K024/mt5-zh-ja-en-trimmed"
# pipe = Text2TextGenerationPipeline(
#   model=MT5ForConditionalGeneration.from_pretrained(path),
#   tokenizer=T5Tokenizer.from_pretrained(path),
# )

# sentence = "ja2zh: 吾輩は猫である。名前はまだ無い。"
# res = pipe(sentence, max_length=100, num_beams=4)
# res[0]['generated_text']
# Out:
# Downloading:   0%|          | 0.00/711 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.23G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.44M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/275 [00:00<?, ?B/s]
# '吾辈是猫。名字还没有。'

# %%
# sentence = "en2zh: I am a cat and I don't have a name yet"
# res = pipe(sentence, max_length=100, num_beams=4)
# res[0]['generated_text']
# Out:
# '我是一个猫,我还没有名字。'

# %%
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# src_text = [
#     "en2zh: I am a cat and I don't have a name yet",
# ]

# model_name = "K024/mt5-zh-ja-en-trimmed"
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))
# tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]

# %%
# print(tgt_text)
# Out:
# ['我是个猫,我还没有名字']
