# %%
# %cd drive/MyDrive/RL/project/RL4LMs/
# Out:
# /content/drive/MyDrive/RL/project/RL4LMs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install -e .

# %%
# # For using Colab Premium GPU (A100)
# !pip3 install torch==1.9.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# # Restart the runtime for installation
# import os
# os.kill(os.getpid(), 9)

# %%
# import wandb
# wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python ./scripts/training/train_text_generation.py --config_path scripts/training/task_configs/iwslt2017/en_zh_supervised.yml
# Out:
# 2022-11-28 05:20:55.827418: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Traceback (most recent call last):
#   File "./scripts/training/train_text_generation.py", line 90, in <module>
#     args.log_to_wandb,
#   File "./scripts/training/train_text_generation.py", line 43, in main
#     tracker=tracker,
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/training_utils.py", line 245, in __init__
#     self._setup()
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/training_utils.py", line 263, in _setup
#     self._tokenizer = build_tokenizer(self._tokenizer_config)
#   File "/content/drive/MyDrive/RL/project/RL4LMs/rl4lms/envs/text_generation/training_utils.py", line 37, in build_tokenizer
#     tokenizer_config["model_name"])
#   File "/usr/local/lib/python3.7/dist-packages/transformers/models/auto/tokenization_auto.py", line 528, in from_pretrained
#     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py", line 1727, in from_pretrained
#     user_agent=user_agent,
#   File "/usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py", line 290, in cached_path
#     local_files_only=local_files_only,
#   File "/usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py", line 585, in get_from_cache
#     http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py", line 424, in http_get
#     _raise_for_status(r)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py", line 413, in _raise_for_status
#     request.raise_for_status()
#   File "/usr/local/lib/python3.7/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 504 Server Error: Gateway Time-out for url: https://huggingface.co/K024/mt5-zh-ja-en-trimmed/resolve/main/special_tokens_map.json

# %%
# !nvidia-smi

# %%
# !python3 rl4lms/envs/text_generation/logging_utils.py
# Out:
# [11/27/22 22:28:52] DEBUG    2022-11-27 22:28:52,264 [DEBUG] Failed  ]8;id=100474;file:///usr/local/lib/python3.7/dist-packages/git/util.py\util.py]8;;\:]8;id=652613;file:///usr/local/lib/python3.7/dist-packages/git/util.py#405\405]8;;\
#                              checking if running in CYGWIN due to:
#                              FileNotFoundError(2, "No such file or
#                              directory: '/usr/bin/uname'")
#                     DEBUG    2022-11-27 22:28:52,274 [DEBUG]          ]8;id=292973;file:///usr/local/lib/python3.7/dist-packages/git/cmd.py\cmd.py]8;;\:]8;id=472675;file:///usr/local/lib/python3.7/dist-packages/git/cmd.py#937\937]8;;\
#                              Popen(['git', 'rev-parse',
#                              '--show-toplevel'], cwd=/content/drive/M
#                              yDrive/RL/project/RL4LMs,
#                              universal_newlines=False, shell=None,
#                              istream=None)
#                     DEBUG    2022-11-27 22:28:52,301       ]8;id=989186;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=312553;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#943\943]8;;\
#                              [DEBUG] Starting new HTTPS
#                              connection (1):
#                              api.wandb.ai:443
#                     DEBUG    2022-11-27 22:28:52,533       ]8;id=990064;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=572865;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#442\442]8;;\
#                              [DEBUG]
#                              https://api.wandb.ai:443
#                              "POST /graphql HTTP/1.1" 200
#                              None
#                     DEBUG    2022-11-27 22:28:52,539       ]8;id=982550;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=101964;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#943\943]8;;\
#                              [DEBUG] Starting new HTTPS
#                              connection (1):
#                              api.wandb.ai:443
#                     DEBUG    2022-11-27 22:28:52,767       ]8;id=421677;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=166050;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#442\442]8;;\
#                              [DEBUG]
#                              https://api.wandb.ai:443
#                              "POST /graphql HTTP/1.1" 200
#                              None
# wandb: Currently logged in as: borrison (use `wandb login --relogin` to force relogin)
# [11/27/22 22:28:54] DEBUG    2022-11-27 22:28:54,458 [DEBUG]          ]8;id=941391;file:///usr/local/lib/python3.7/dist-packages/git/cmd.py\cmd.py]8;;\:]8;id=339062;file:///usr/local/lib/python3.7/dist-packages/git/cmd.py#937\937]8;;\
#                              Popen(['git', 'cat-file',
#                              '--batch-check'], cwd=/content/drive/MyD
#                              rive/RL/project/RL4LMs,
#                              universal_newlines=False, shell=None,
#                              istream=<valid stream>)
# 2022-11-27 22:29:01.150920: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# wandb: wandb version 0.13.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.15
# wandb: Run data is saved locally in /content/drive/MyDrive/RL/project/RL4LMs/wandb/run-20221127_222852-2bxc5079
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run test_run
# wandb: ⭐️ View project at https://wandb.ai/borrison/test_proj
# wandb: 🚀 View run at https://wandb.ai/borrison/test_proj/runs/2bxc5079
# [11/27/22 22:29:03] INFO     2022-11-27 22:29:03,460 [INFO]  ]8;id=345690;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=839013;file://rl4lms/envs/text_generation/logging_utils.py#76\76]8;;\
#                              Split val predictions
#                     INFO     2022-11-27 22:29:03,462 [INFO]  ]8;id=622220;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=11707;file://rl4lms/envs/text_generation/logging_utils.py#78\78]8;;\
#                              {'sample_id': '1',
#                              'prompt_text': 'Hello',
#                              'gen_text': 'I am there'}
#                     INFO     2022-11-27 22:29:03,464 [INFO]  ]8;id=187249;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=811245;file://rl4lms/envs/text_generation/logging_utils.py#78\78]8;;\
#                              {'sample_id': '2',
#                              'prompt_text': 'Hi',
#                              'gen_text': 'there'}
#                     DEBUG    2022-11-27 22:29:03,492       ]8;id=139855;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=747125;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#943\943]8;;\
#                              [DEBUG] Starting new HTTPS
#                              connection (1):
#                              api.wandb.ai:443
#                     DEBUG    2022-11-27 22:29:03,729       ]8;id=547581;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=478407;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#442\442]8;;\
#                              [DEBUG]
#                              https://api.wandb.ai:443
#                              "POST /graphql HTTP/1.1" 200
#                              None
#                     DEBUG    2022-11-27 22:29:03,756       ]8;id=113392;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=847972;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#943\943]8;;\
#                              [DEBUG] Starting new HTTPS
#                              connection (1):
#                              api.wandb.ai:443
#                     DEBUG    2022-11-27 22:29:03,984       ]8;id=70371;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=767734;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#442\442]8;;\
#                              [DEBUG]
#                              https://api.wandb.ai:443
#                              "POST /graphql HTTP/1.1" 200
#                              None
#                     DEBUG    2022-11-27 22:29:03,990       ]8;id=373458;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=942191;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#943\943]8;;\
#                              [DEBUG] Starting new HTTPS
#                              connection (1):
#                              api.wandb.ai:443
# [11/27/22 22:29:04] DEBUG    2022-11-27 22:29:04,218       ]8;id=682138;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=334097;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#442\442]8;;\
#                              [DEBUG]
#                              https://api.wandb.ai:443
#                              "POST /graphql HTTP/1.1" 200
#                              None
#                     INFO     2022-11-27 22:29:04,226 [INFO] ]8;id=67342;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=892938;file://rl4lms/envs/text_generation/logging_utils.py#119\119]8;;\
#                              val metrics: {'epoch': 1,
#                              'metrics': {'metric_1': 0.05,
#                              'metric_2': 0.1}}
#                     INFO     2022-11-27 22:29:04,228 [INFO]  ]8;id=889818;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=895835;file://rl4lms/envs/text_generation/logging_utils.py#76\76]8;;\
#                              Split val predictions
#                     INFO     2022-11-27 22:29:04,230 [INFO]  ]8;id=120932;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=692975;file://rl4lms/envs/text_generation/logging_utils.py#78\78]8;;\
#                              {'sample_id': '1',
#                              'prompt_text': 'Hello',
#                              'gen_text': 'I am there'}
#                     INFO     2022-11-27 22:29:04,232 [INFO]  ]8;id=357209;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=3867;file://rl4lms/envs/text_generation/logging_utils.py#78\78]8;;\
#                              {'sample_id': '2',
#                              'prompt_text': 'Hi',
#                              'gen_text': 'there'}
#                     DEBUG    2022-11-27 22:29:04,246       ]8;id=236872;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=621115;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#943\943]8;;\
#                              [DEBUG] Starting new HTTPS
#                              connection (1):
#                              api.wandb.ai:443
#                     DEBUG    2022-11-27 22:29:04,489       ]8;id=506969;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=471018;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#442\442]8;;\
#                              [DEBUG]
#                              https://api.wandb.ai:443
#                              "POST /graphql HTTP/1.1" 200
#                              None
#                     INFO     2022-11-27 22:29:04,509 [INFO] ]8;id=75223;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=695186;file://rl4lms/envs/text_generation/logging_utils.py#119\119]8;;\
#                              val metrics: {'epoch': 2,
#                              'metrics': {'metric_1': 0.06,
#                              'metric_2': 0.2}}
#                     INFO     2022-11-27 22:29:04,511 [INFO]  ]8;id=503459;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=207332;file://rl4lms/envs/text_generation/logging_utils.py#76\76]8;;\
#                              Split val predictions
#                     INFO     2022-11-27 22:29:04,513 [INFO]  ]8;id=726403;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=50029;file://rl4lms/envs/text_generation/logging_utils.py#78\78]8;;\
#                              {'sample_id': '1',
#                              'prompt_text': 'Hello',
#                              'gen_text': 'I am there'}
#                     INFO     2022-11-27 22:29:04,514 [INFO]  ]8;id=132237;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=319914;file://rl4lms/envs/text_generation/logging_utils.py#78\78]8;;\
#                              {'sample_id': '2',
#                              'prompt_text': 'Hi',
#                              'gen_text': 'there'}
#                     DEBUG    2022-11-27 22:29:04,529       ]8;id=484629;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=307706;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#943\943]8;;\
#                              [DEBUG] Starting new HTTPS
#                              connection (1):
#                              api.wandb.ai:443
#                     DEBUG    2022-11-27 22:29:04,758       ]8;id=910778;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py\connectionpool.py]8;;\:]8;id=108650;file:///usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py#442\442]8;;\
#                              [DEBUG]
#                              https://api.wandb.ai:443
#                              "POST /graphql HTTP/1.1" 200
#                              None
#                     INFO     2022-11-27 22:29:04,777 [INFO] ]8;id=473810;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=862403;file://rl4lms/envs/text_generation/logging_utils.py#119\119]8;;\
#                              val metrics: {'epoch': 3,
#                              'metrics': {'metric_1': 0.06,
#                              'metric_2': 0.3}}
#                     INFO     2022-11-27 22:29:04,779 [INFO] ]8;id=131580;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=644905;file://rl4lms/envs/text_generation/logging_utils.py#122\122]8;;\
#                              Rollout Info: {'ep_len': 2,
#                              'ep_reward': 0.4}
#                     INFO     2022-11-27 22:29:04,781 [INFO] ]8;id=541362;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=173496;file://rl4lms/envs/text_generation/logging_utils.py#122\122]8;;\
#                              Rollout Info: {'ep_len': 3,
#                              'ep_reward': 0.5}
#                     INFO     2022-11-27 22:29:04,783 [INFO] ]8;id=854527;file://rl4lms/envs/text_generation/logging_utils.py\logging_utils.py]8;;\:]8;id=485482;file://rl4lms/envs/text_generation/logging_utils.py#122\122]8;;\
#                              Rollout Info: {'ep_len': 3,
#                              'ep_reward': 0.5}
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb:       ep_len ▁██
# wandb:    ep_reward ▁██
# wandb:        epoch ▁▅█
# wandb: val/metric_1 ▁██
# wandb: val/metric_2 ▁▄█
# wandb:
# wandb: Run summary:
# wandb:       ep_len 3
# wandb:    ep_reward 0.5
# wandb:        epoch 3
# wandb: val/metric_1 0.06
# wandb: val/metric_2 0.3
# wandb:
# wandb: Synced test_run: https://wandb.ai/borrison/test_proj/runs/2bxc5079
# wandb: Synced 5 W&B file(s), 3 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20221127_222852-2bxc5079/logs

# %%
from transformers import (
  T5Tokenizer,
  MT5ForConditionalGeneration,
  Text2TextGenerationPipeline,
)

path = "K024/mt5-zh-ja-en-trimmed"
pipe = Text2TextGenerationPipeline(
  model=MT5ForConditionalGeneration.from_pretrained(path),
  tokenizer=T5Tokenizer.from_pretrained(path),
)

sentence = "ja2zh: 吾輩は猫である。名前はまだ無い。"
res = pipe(sentence, max_length=100, num_beams=4)
res[0]['generated_text']
# Out:
# Downloading:   0%|          | 0.00/711 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.23G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.44M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/275 [00:00<?, ?B/s]
# '吾辈是猫。名字还没有。'

# %%
sentence = "en2zh: I am a cat and I don't have a name yet"
res = pipe(sentence, max_length=100, num_beams=4)
res[0]['generated_text']
# Out:
# '我是一个猫,我还没有名字。'

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

src_text = [
    "en2zh: I am a cat and I don't have a name yet",
]

model_name = "K024/mt5-zh-ja-en-trimmed"
tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))
tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]

# %%
print(tgt_text)
# Out:
# ['我是个猫,我还没有名字']
